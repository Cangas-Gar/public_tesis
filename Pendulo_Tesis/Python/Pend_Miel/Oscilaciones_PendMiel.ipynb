# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# function that returns dy/dt
def pend_miel(x,t,gamma):
    dxdt = gamma - np.sin(x)
    return dxdt
gamma = 50
x0 = 1

# %%
#Intervalo de tiempo
t1 = np.linspace(0,500,5000)
#Solucion de EDO
x1 = odeint(pend_miel,x0,t1,args=(gamma,))

#Plotting
fig, ax = plt.subplots(figsize=(10,5), dpi=80)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

ax.set_ylim()
plt.yticks([gamma],
       [gamma])
ax.plot(t1,pend_miel(x1,t1,gamma),'k',linewidth=2, linestyle="-", label='$\gamma=50$')
plt.xlabel('time')
plt.ylabel('$\dot{\Theta}$')
plt.ylim((0,70))
plt.xlim((0,500))
plt.legend()

fig.savefig("vel_vs_t_gamma_50_Pend_Miel.png",dpi=72)
plt.show()

# %%
#Intervalo de tiempo
t1 = np.linspace(0,10,500)
#Solucion de EDO
x1 = odeint(pend_miel,x0,t1,args=(gamma,))

#Plotting
fig, ax = plt.subplots(figsize=(10,5), dpi=80)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

y_ticks = np.arange(0, 5, 1)
plt.yticks(y_ticks)
ax.yaxis.get_major_ticks()[0].label1.set_visible(False)

ax.plot(t1,pend_miel(x1,t1,gamma),'k',linewidth=2, linestyle="-", label='$\gamma=2$')
plt.xlabel('time')
plt.ylabel('$\dot{\Theta}$')
plt.ylim((0,100))
plt.legend()

fig.savefig("vel_vs_t_gamma_2_Pend_Miel.png",dpi=72)
plt.show()

# %%
#Intervalo de tiempo
t1 = np.linspace(0,35,500)
#Solucion de EDO
x1 = odeint(pend_miel,x0,t1,args=(gamma,))

#Plotting
fig, ax = plt.subplots(figsize=(10,5), dpi=80)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
 
y_ticks = np.arange(0, 5, 1)
plt.yticks(y_ticks)
ax.yaxis.get_major_ticks()[0].label1.set_visible(False)
    
ax.plot(t1,pend_miel(x1,t1,gamma),'k',linewidth=2, linestyle="-", label='$\gamma=1.1$')
plt.xlabel('time')
plt.ylabel('$\dot{\Theta}$')
plt.ylim((0,3))
plt.legend()

fig.savefig("vel_vs_t_gamma_1.1_Pend_Miel.png",dpi=72)
plt.show()

# %%
#Intervalo de tiempo
t4 = np.linspace(0,12,500)
#Solucion de EDO
x1 = odeint(pend_miel,x0,t4,args=(gamma,))

#Plotting
fig, ax = plt.subplots(figsize=(10,5), dpi=80)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
 
y_ticks = np.arange(0, 5, 1)
plt.yticks(y_ticks)
ax.yaxis.get_major_ticks()[0].label1.set_visible(False)
    
ax.plot(t1,pend_miel(x1,t1,gamma),'k',linewidth=2, linestyle="-", label='$\gamma=1$')
plt.xlabel('time')
plt.ylabel('$\dot{\Theta}$')
plt.ylim((0,3))
plt.legend()

fig.savefig("vel_vs_t_gamma_1_Pend_Miel.png",dpi=72)
plt.show()

# %%
#Intervalo de tiempo
t4 = np.linspace(0,25,500)
#Solucion de EDO
x1 = odeint(pend_miel,x0,t4,args=(gamma,))

#Plotting
fig, ax = plt.subplots(figsize=(10,5), dpi=80)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
 
y_ticks = np.arange(-1, 2, 1)
plt.yticks(y_ticks)

ax.xaxis.get_major_ticks()[0].label1.set_visible(False)
    
ax.plot(t1,pend_miel(x1,t1,gamma),'k',linewidth=2, linestyle="-", label='$\gamma=0.9$')
plt.xlabel('time')
plt.ylabel('$\dot{\Theta}$')
plt.ylim((-1,1))
plt.xlim((0,25))
plt.legend()

fig.savefig("vel_vs_t_gamma_0.9_Pend_Miel.png",dpi=72)
plt.show()

# %%
#Intervalo de tiempo
t4 = np.linspace(0,0.25,500)
#Solucion de EDO
x1 = odeint(pend_miel,x0,t4,args=(gamma,))

#Plotting
fig, ax = plt.subplots(figsize=(10,5), dpi=80)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
 
y_ticks = np.arange(-1, 2, 1)
plt.yticks(y_ticks)
#ax.yaxis.get_major_ticks()[1].label1.set_visible(False)



ax.xaxis.get_major_ticks()[0].label1.set_visible(False)

ax.plot(t1,pend_miel(x1,t1,gamma),'k',linewidth=2, linestyle="-", label='$\gamma=0.1$')
plt.xlabel('time')
plt.ylabel('$\dot{\Theta}$')
plt.xlim((0,0.25))
plt.ylim((-1,1))
plt.legend()

fig.savefig("vel_vs_t_gamma_0.1_Pend_Miel.png",dpi=72)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ea9a1be41f00> in <module>
#       2 t1 = np.linspace(0,0.25,500)
#       3 #Solucion de EDO
# ----> 4 x1 = odeint(pend_miel,x0,t4,args=(gamma,))
#       5
#       6 #Plotting
#
# NameError: name 't4' is not defined
